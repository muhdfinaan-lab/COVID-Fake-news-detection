# %%
# !pip install pandas
# !pip install opendatasets
import opendatasets as od
import pandas as pd

# %%
od.download('https://www.kaggle.com/datasets/elvinagammed/covid19-fake-news-dataset-nlp/croissant/download')
# Out:
# Skipping, found downloaded files in "./covid19-fake-news-dataset-nlp" (use force=True to force download)

# %%
df = pd.read_csv('/content/covid19-fake-news-dataset-nlp/Constraint_Train.csv')

# %%
df
# Out:
#         id                                              tweet label
# 0        1  The CDC currently reports 99031 deaths. In gen...  real
# 1        2  States reported 1121 deaths a small rise from ...  real
# 2        3  Politically Correct Woman (Almost) Uses Pandem...  fake
# 3        4  #IndiaFightsCorona: We have 1524 #COVID testin...  real
# 4        5  Populous states can generate large case counts...  real
# ...    ...                                                ...   ...
# 6415  6416  A tiger tested positive for COVID-19 please st...  fake
# 6416  6417  ???Autopsies prove that COVID-19 is??� a blood...  fake
# 6417  6418  _A post claims a COVID-19 vaccine has already ...  fake
# 6418  6419  Aamir Khan Donate 250 Cr. In PM Relief Cares Fund  fake
# 6419  6420  It has been 93 days since the last case of COV...  real
#
# [6420 rows x 3 columns]

# %%
# !pip install emoji

# %%
import re
import string
import nltk
import emoji
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['label'] = le.fit_transform(df['label'])

label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

print(label_mapping)
# Out:
# {'fake': np.int64(0), 'real': np.int64(1)}

# %%
all_stop_words = stopwords.words('english')

lemma = WordNetLemmatizer()

def rem_links(text):
  text = re.sub(r'http[s]?://\s+','',str(text))
  return text

def deemojize(text):
  return emoji.demojize(str(text))

def rem_punch(text):
  text = str(text)
  for punctuation in string.punctuation:
    text = text.replace(punctuation,'')
  return text

def stopping_words(text):
  stop = set(all_stop_words)
  return[i for i in text if i not in stop and i != '']

def lemmas(text):
  if not isinstance(text,list) or len(text) == 0:
    return[]
  return[lemma.lemmatize(word) for word in text]

def token(text):
  return re.split(r'\s+',str(text).strip())

# %%
df['pre_pro'] = df['tweet'].fillna('')

df['pre_pro'] = df['pre_pro'].apply(rem_links)
df['pre_pro'] = df['pre_pro'].apply(deemojize)
df['pre_pro'] = df['pre_pro'].apply(rem_punch)
df['pre_pro'] = df['pre_pro'].apply(lambda x:x.lower())
df['pre_pro'] = df['pre_pro'].apply(token)
df['pre_pro'] = df['pre_pro'].apply(stopping_words)
df['pre_pro'] = df['pre_pro'].apply(lemmas)

# %%
df.head()
# Out:
#    id                                              tweet  label  \
# 0   1  The CDC currently reports 99031 deaths. In gen...      1
# 1   2  States reported 1121 deaths a small rise from ...      1
# 2   3  Politically Correct Woman (Almost) Uses Pandem...      0
# 3   4  #IndiaFightsCorona: We have 1524 #COVID testin...      1
# 4   5  Populous states can generate large case counts...      1
#
#                                              pre_pro
# 0  [cdc, currently, report, 99031, death, general...
# 1  [state, reported, 1121, death, small, rise, la...
# 2  [politically, correct, woman, almost, us, pand...
# 3  [indiafightscorona, 1524, covid, testing, labo...
# 4  [populous, state, generate, large, case, count...

# %%
df['cleaned_text'] = df['pre_pro'].apply(lambda x:' '.join(x))

# %%
df['cleaned_text'].value_counts()
# Out:
# cleaned_text
# people starting enter er fungal lung infection wearing mask                                                                                                                                                                                     2
# photo vaccine developed u scientist covid19                                                                                                                                                                                                     2
# video clip show doctor couple died treating 134 covid19 patient                                                                                                                                                                                 2
# video u president donald trump top u pharmaceutical executive speaking press conference viewed thousand time multiple facebook twitter youtube post alongside claim show announcing vaccine novel coronavirus covid19 ready administered        2
# ...

# %%
df.head()
# Out:
#    id                                              tweet  label  \
# 0   1  The CDC currently reports 99031 deaths. In gen...      1
# 1   2  States reported 1121 deaths a small rise from ...      1
# 2   3  Politically Correct Woman (Almost) Uses Pandem...      0
# 3   4  #IndiaFightsCorona: We have 1524 #COVID testin...      1
# 4   5  Populous states can generate large case counts...      1
#
#                                              pre_pro  \
# 0  [cdc, currently, report, 99031, death, general...
# 1  [state, reported, 1121, death, small, rise, la...
# 2  [politically, correct, woman, almost, us, pand...
# 3  [indiafightscorona, 1524, covid, testing, labo...
# 4  [populous, state, generate, large, case, count...
#
#                                         cleaned_text
# 0  cdc currently report 99031 death general discr...
# 1  state reported 1121 death small rise last tues...
# 2  politically correct woman almost us pandemic e...
# ...

# %%
tf=TfidfVectorizer(max_features=5000)

x=tf.fit_transform(df['cleaned_text']).toarray()
y=df['label']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier(random_state=42)

dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import classification_report
y_pred=dtc.predict(x_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       616
#            1       0.84      0.87      0.85       668
#
#     accuracy                           0.84      1284
#    macro avg       0.84      0.84      0.84      1284
# weighted avg       0.84      0.84      0.84      1284

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       616
#            1       0.93      0.90      0.92       668
#
#     accuracy                           0.91      1284
#    macro avg       0.91      0.92      0.91      1284
# weighted avg       0.92      0.91      0.91      1284

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89       616
#            1       0.94      0.83      0.88       668
#
#     accuracy                           0.88      1284
#    macro avg       0.89      0.89      0.88      1284
# weighted avg       0.89      0.88      0.88      1284

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc=GradientBoostingClassifier()

gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred=gbc.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       616
#            1       0.91      0.86      0.89       668
#
#     accuracy                           0.88      1284
#    macro avg       0.89      0.89      0.88      1284
# weighted avg       0.89      0.88      0.88      1284

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92       616
#            1       0.93      0.93      0.93       668
#
#     accuracy                           0.93      1284
#    macro avg       0.93      0.93      0.93      1284
# weighted avg       0.93      0.93      0.93      1284
